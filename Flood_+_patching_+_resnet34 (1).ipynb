# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 9.0MB/s
#      |████████████████████████████████| 194kB 50.9MB/s
#      |████████████████████████████████| 51kB 7.5MB/s
#      |████████████████████████████████| 1.0MB 52.6MB/s
#      |████████████████████████████████| 51kB 8.6MB/s
#      |████████████████████████████████| 51kB 8.5MB/s
#      |████████████████████████████████| 40kB 5.7MB/s
#      |████████████████████████████████| 92kB 14.2MB/s
#      |████████████████████████████████| 61kB 11.1MB/s
#      |████████████████████████████████| 51kB 9.1MB/s
#      |████████████████████████████████| 2.6MB 47.4MB/s
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from fastai.vision.all import *
from fastai.data.all import *
from fastai.imports import *
from fastai.vision.core import *
from fastai import metrics
torch.cuda.get_device_properties(0).total_memory
# Out:
# 15812263936

# %%
path=Path("/content/drive/My Drive/DATA_HAR")

# %% [markdown]
# # **DATA BLOCK AND LOADER**

# %%
def get_tuple_files(path):
    files = get_image_files(path)
    files = files.filter(lambda f: f.name.endswith('vhr.tif'),negate=False)
    return files

# %%
def label_func(x):
      return str(x.parents[0]/x.stem[0:23])+"_mask_flood.tif";

# %%
 seg = DataBlock(blocks=(ImageBlock(), MaskBlock( codes =['n','y'])),
                
    item_tfms=[Resize(512,method='squish',resamples=(Image.BICUBIC,Image.BICUBIC)),ToTensor],
    batch_tfms=[IntToFloatTensor(),Normalize.from_stats(*imagenet_stats)],
    
    get_items=get_tuple_files,            
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=label_func)

# %%
seg.summary(path)
# Out:
# Setting-up type transforms pipelines
# Collecting items from /content/drive/My Drive/DATA_HAR
# Found 3712 items
# 2 datasets of sizes 2970,742
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: label_func -> PILBase.create
#
# Building one sample
#   Pipeline: PILBase.create
#     starting from
#       /content/drive/My Drive/DATA_HAR/E244100N3304900UTM15R_2_vhr.tif
#     applying PILBase.create gives
#       PILImage mode=RGB size=512x512
#   Pipeline: label_func -> PILBase.create
#     starting from
#       /content/drive/My Drive/DATA_HAR/E244100N3304900UTM15R_2_vhr.tif
#     applying label_func gives
#       /content/drive/My Drive/DATA_HAR/E244100N3304900UTM15R_2_mask_flood.tif
#     applying PILBase.create gives
#       PILMask mode=L size=512x512
#
# Final sample: (PILImage mode=RGB size=512x512, PILMask mode=L size=512x512)
#
#
# Setting up after_item: Pipeline: AddMaskCodes -> Resize -- {'size': (512, 512), 'method': 'squish', 'pad_mode': 'reflection', 'resamples': (3, 3), 'p': 1.0} -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} -> Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)}
#
# Building one batch
# Applying item_tfms to the first sample:
#   Pipeline: AddMaskCodes -> Resize -- {'size': (512, 512), 'method': 'squish', 'pad_mode': 'reflection', 'resamples': (3, 3), 'p': 1.0} -> ToTensor
#     starting from
#       (PILImage mode=RGB size=512x512, PILMask mode=L size=512x512)
#     applying AddMaskCodes gives
#       (PILImage mode=RGB size=512x512, PILMask mode=L size=512x512)
#     applying Resize -- {'size': (512, 512), 'method': 'squish', 'pad_mode': 'reflection', 'resamples': (3, 3), 'p': 1.0} gives
#       (PILImage mode=RGB size=512x512, PILMask mode=L size=512x512)
#     applying ToTensor gives
#       (TensorImage of size 3x512x512, TensorMask of size 512x512)
#
# Adding the next 3 samples
#
# No before_batch transform to apply
#
# Collating items in a batch
#
# Applying batch_tfms to the batch built
#   Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} -> Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)}
#     starting from
#       (TensorImage of size 4x3x512x512, TensorMask of size 4x512x512)
#     applying IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} gives
#       (TensorImage of size 4x3x512x512, TensorMask of size 4x512x512)
#     applying Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)} gives
#       (TensorImage of size 4x3x512x512, TensorMask of size 4x512x512)

# %%
dls = seg.dataloaders(path,bs=8)
dls.show_batch()

# %%
b = dls.one_batch()

# %%
plt.imshow(b[0][0][2].cpu().numpy())

# %%
plt.imshow(b[1][0].cpu().numpy())

# %% [markdown]
# # **MODEL SUMMARY**

# %%
learn= unet_learner(dls,resnet34, metrics=[Dice()])

learn.summary()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>
# DynamicUnet (Input shape: ['8 x 3 x 512 x 512'])
# ================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ================================================================
# Conv2d               8 x 64 x 256 x 256   9,408      False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 256 x 256   128        True
# ________________________________________________________________
# ReLU                 8 x 64 x 256 x 256   0          False
# ________________________________________________________________
# MaxPool2d            8 x 64 x 128 x 128   0          False
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# ReLU                 8 x 64 x 128 x 128   0          False
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# ReLU                 8 x 64 x 128 x 128   0          False
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# ReLU                 8 x 64 x 128 x 128   0          False
# ________________________________________________________________
# Conv2d               8 x 64 x 128 x 128   36,864     False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    73,728     False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# ReLU                 8 x 128 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    8,192      False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# ReLU                 8 x 128 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# ReLU                 8 x 128 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# ReLU                 8 x 128 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 128 x 64 x 64    147,456    False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    294,912    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    32,768     False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# ReLU                 8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 32 x 32    589,824    False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    1,179,648  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# ReLU                 8 x 512 x 16 x 16    0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    2,359,296  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    131,072    False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    2,359,296  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# ReLU                 8 x 512 x 16 x 16    0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    2,359,296  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    2,359,296  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# ReLU                 8 x 512 x 16 x 16    0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    2,359,296  False
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# BatchNorm2d          8 x 512 x 16 x 16    1,024      True
# ________________________________________________________________
# ReLU                 8 x 512 x 16 x 16    0          False
# ________________________________________________________________
# Conv2d               8 x 1024 x 16 x 16   4,719,616  True
# ________________________________________________________________
# ReLU                 8 x 1024 x 16 x 16   0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 16 x 16    4,719,104  True
# ________________________________________________________________
# ReLU                 8 x 512 x 16 x 16    0          False
# ________________________________________________________________
# Conv2d               8 x 1024 x 16 x 16   525,312    True
# ________________________________________________________________
# ReLU                 8 x 1024 x 16 x 16   0          False
# ________________________________________________________________
# PixelShuffle         8 x 256 x 32 x 32    0          False
# ________________________________________________________________
# BatchNorm2d          8 x 256 x 32 x 32    512        True
# ________________________________________________________________
# Conv2d               8 x 512 x 32 x 32    2,359,808  True
# ________________________________________________________________
# ReLU                 8 x 512 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 32 x 32    2,359,808  True
# ________________________________________________________________
# ReLU                 8 x 512 x 32 x 32    0          False
# ________________________________________________________________
# ReLU                 8 x 512 x 32 x 32    0          False
# ________________________________________________________________
# Conv2d               8 x 1024 x 32 x 32   525,312    True
# ________________________________________________________________
# ReLU                 8 x 1024 x 32 x 32   0          False
# ________________________________________________________________
# PixelShuffle         8 x 256 x 64 x 64    0          False
# ________________________________________________________________
# BatchNorm2d          8 x 128 x 64 x 64    256        True
# ________________________________________________________________
# Conv2d               8 x 384 x 64 x 64    1,327,488  True
# ________________________________________________________________
# ReLU                 8 x 384 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 384 x 64 x 64    1,327,488  True
# ________________________________________________________________
# ReLU                 8 x 384 x 64 x 64    0          False
# ________________________________________________________________
# ReLU                 8 x 384 x 64 x 64    0          False
# ________________________________________________________________
# Conv2d               8 x 768 x 64 x 64    295,680    True
# ________________________________________________________________
# ReLU                 8 x 768 x 64 x 64    0          False
# ________________________________________________________________
# PixelShuffle         8 x 192 x 128 x 128  0          False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 128 x 128   128        True
# ________________________________________________________________
# Conv2d               8 x 256 x 128 x 128  590,080    True
# ________________________________________________________________
# ReLU                 8 x 256 x 128 x 128  0          False
# ________________________________________________________________
# Conv2d               8 x 256 x 128 x 128  590,080    True
# ________________________________________________________________
# ReLU                 8 x 256 x 128 x 128  0          False
# ________________________________________________________________
# ReLU                 8 x 256 x 128 x 128  0          False
# ________________________________________________________________
# Conv2d               8 x 512 x 128 x 128  131,584    True
# ________________________________________________________________
# ReLU                 8 x 512 x 128 x 128  0          False
# ________________________________________________________________
# PixelShuffle         8 x 128 x 256 x 256  0          False
# ________________________________________________________________
# BatchNorm2d          8 x 64 x 256 x 256   128        True
# ________________________________________________________________
# Conv2d               8 x 96 x 256 x 256   165,984    True
# ________________________________________________________________
# ReLU                 8 x 96 x 256 x 256   0          False
# ________________________________________________________________
# Conv2d               8 x 96 x 256 x 256   83,040     True
# ________________________________________________________________
# ReLU                 8 x 96 x 256 x 256   0          False
# ________________________________________________________________
# ReLU                 8 x 192 x 256 x 256  0          False
# ________________________________________________________________
# Conv2d               8 x 384 x 256 x 256  37,248     True
# ________________________________________________________________
# ReLU                 8 x 384 x 256 x 256  0          False
# ________________________________________________________________
# PixelShuffle         8 x 96 x 512 x 512   0          False
# ________________________________________________________________
# ResizeToOrig         8 x 96 x 512 x 512   0          False
# ________________________________________________________________
# MergeLayer           8 x 99 x 512 x 512   0          False
# ________________________________________________________________
# Conv2d               8 x 99 x 512 x 512   88,308     True
# ________________________________________________________________
# ReLU                 8 x 99 x 512 x 512   0          False
# ________________________________________________________________
# Conv2d               8 x 99 x 512 x 512   88,308     True
# ________________________________________________________________
# Sequential           8 x 99 x 512 x 512   0          False
# ________________________________________________________________
# ReLU                 8 x 99 x 512 x 512   0          False
# ________________________________________________________________
# Conv2d               8 x 2 x 512 x 512    200        True
# ________________________________________________________________
#
# Total params: 41,221,168
# Total trainable params: 19,953,520
# Total non-trainable params: 21,267,648
#
# Optimizer used: <function Adam at 0x7fa003171c80>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback

# %%
learn.load("/content/drive/My Drive/patch-build")

# %% [markdown]
# # **TRAINING**

# %%
learn.fine_tune(5,base_lr=2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.110172</td>
#       <td>0.104193</td>
#       <td>0.425963</td>
#       <td>13:18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.064217</td>
#       <td>0.071110</td>
#       <td>0.766718</td>
#       <td>12:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.051145</td>
#       <td>0.052365</td>
#       <td>0.791999</td>
#       <td>12:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.043599</td>
#       <td>0.042342</td>
#       <td>0.839813</td>
#       <td>12:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.035769</td>
#       <td>0.037593</td>
#       <td>0.862610</td>
#       <td>12:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.031380</td>
#       <td>0.036845</td>
#       <td>0.865498</td>
#       <td>12:47</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save("patch-flood")
# Out:
# Path('models/patch-flood.pth')

# %%
learn.export("patch-flooded.pkl")

# %% [markdown]
# # **TESTING**

# %%
im=PILImage.create("/content/drive/My Drive/E246000N3305300UTM15R/vhr.tif")
im_mask_flood=PILMask.create("/content/drive/My Drive/E246000N3305300UTM15R/flooded1m.tif")

z=im.reshape(1024,1024,resample=3)

z=image2tensor(z)
z=z[:,0:512,0:512]
z=z.permute((1,2,0))
im=PILImage.create(z.cpu().numpy())

zm=im_mask_flood.reshape(1024,1024,resample=3)

zm=image2tensor(zm)
zm=zm[-1,0:512,0:512]
im_mask=PILMask.create(zm.cpu().numpy())

# %% [markdown]
# Image and Mask

# %%
im.show()
im_mask.show()

# %% [markdown]
# Prediction

# %%
PILMask.create(learn.predict(im)[0]).show()
